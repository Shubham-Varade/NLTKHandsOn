# %%
#Chinese segmentation using jieba
# !pip install jieba
import jieba
text=jieba.cut("把句子中所有的可以成词的词语都扫描出来",cut_all=True)
print(" ".join(text))
# Out:
# ...
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\shubham\AppData\Local\Temp\jieba.cache
# Loading model cost 0.775 seconds.
# Prefix dict has been built successfully.
# 把 句子 中所 所有 的 可以 成 词 的 词语 都 扫描 描出 描出来 出来

# %%
#Task 1: Basic Text Processing Pipeline
import nltk
texts="""Months on ye at by esteem desire warmth former. Sure that that way gave any fond now. His boy middleton sir nor engrossed affection excellent. Dissimilar compliment cultivated preference eat sufficient may. Well next door soon we mr he four. Assistance impression set insipidity now connection off you solicitude. Under as seems we me stuff those style at. Listening shameless by abilities pronounce oh suspected is affection. Next it draw in draw much bred. """
tagged=[]
for text in texts:
    sentences=nltk.sent_tokenize(texts)
    for sentence in sentences:
        words=nltk.word_tokenize(sentence)
        tagged+=nltk.pos_tag(words)
tagged
# Out:
# [('Months', 'NNS'),
#  ('on', 'IN'),
#  ('ye', 'NN'),
#  ('at', 'IN'),
#  ('by', 'IN'),
#  ('esteem', 'JJ'),
#  ('desire', 'NN'),
#  ('warmth', 'NN'),
#  ('former', 'JJ'),
#  ('.', '.'),
#  ('Sure', 'JJ'),
#  ('that', 'IN'),
#  ('that', 'DT'),
#  ('way', 'NN'),
#  ('gave', 'VBD'),
#  ('any', 'DT'),
#  ('fond', 'NN'),
#  ('now', 'RB'),
#  ('.', '.'),
#  ('His', 'PRP$'),
#  ('boy', 'NN'),
#  ('middleton', 'NN'),
#  ('sir', 'NN'),
#  ('nor', 'CC'),
#  ('engrossed', 'JJ'),
#  ('affection', 'NN'),
#  ('excellent', 'NN'),
#  ('.', '.'),
#  ('Dissimilar', 'JJ'),
#  ('compliment', 'NN'),
#  ('cultivated', 'VBD'),
#  ('preference', 'NN'),
#  ('eat', 'NN'),
#  ('sufficient', 'NN'),
#  ('may', 'MD'),
#  ('.', '.'),
#  ('Well', 'RB'),
#  ('next', 'JJ'),
#  ('door', 'NN'),
#  ('soon', 'RB'),
#  ('we', 'PRP'),
#  ('mr', 'VBP'),
#  ('he', 'PRP'),
#  ('four', 'CD'),
#  ('.', '.'),
#  ('Assistance', 'NNP'),
#  ('impression', 'NN'),
#  ('set', 'VBN'),
#  ('insipidity', 'NN'),
#  ('now', 'RB'),
# ...

# %%
#Task 2:TweetTokenizer
import nltk 
from nltk.tokenize import TweetTokenizer
text='The party was super fun :D #SuperFun'
tweet_token=TweetTokenizer()
tweet_token.tokenize(text)
# Out:
# ['The', 'party', 'was', 'super', 'fun', ':D', '#SuperFun']

# %%
#Task3: Scraping Data from Web
from urllib import request
url="http://www.gutenberg.org/files/2554/2554-0.txt"
response=request.urlopen(url)
raw=response.read().decode('utf8')
#type(raw)
#raw[:50]
#print(raw[:50])
from nltk.tokenize import word_tokenize
tokens=word_tokenize(raw)
type(tokens)
print(tokens[:100])
# Out:
# ['\ufeffThe', 'Project', 'Gutenberg', 'EBook', 'of', 'Crime', 'and', 'Punishment', ',', 'by', 'Fyodor', 'Dostoevsky', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', '.', 'You', 'may', 'copy', 'it', ',', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.org', 'Title', ':', 'Crime', 'and', 'Punishment', 'Author', ':', 'Fyodor', 'Dostoevsky', 'Release', 'Date', ':', 'March', '28', ',', '2006', '[', 'EBook', '#', '2554', ']', 'Last', 'Updated', ':', 'October', '27', ',', '2016', 'Language', ':', 'English', 'Character', 'set', 'encoding', ':', 'UTF-8', '*', '*', '*', 'START', 'OF', 'THIS']
